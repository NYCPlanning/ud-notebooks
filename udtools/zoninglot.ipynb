# %%
import os
import sys
import pickle

# %%
# add udtools library to path
home_dir = os.environ.get('HOME')
udtools_module_path = os.path.join(home_dir, 'git', 'ud-tools-core', 'udtools')

if udtools_module_path not in sys.path:
  sys.path.append(udtools_module_path)

# %%
import ipywidgets as widgets

# OCC/pythonocc-core imports
from OCC.Display.WebGl.jupyter_renderer import JupyterRenderer

# udtools imports
from archtools.geometry.boolean import diff
from nyczoning.zoninglot import ZoningLot
from nyczoning.geometry import build_yard_cutter
from nyclanduse.site import Site
from nyclanduse.scenario import Scenario
from nyclanduse.study import Study

# %% [markdown]
# Each of the Zone classes generated with ZoneFactory provides its own `get_additives` and `get_subtractives` method. In the case of `ContextualDistrict`, `get_additives` is not yet implemented. `get_subtractives` in this case first calls `build_height_cutter` to get limiting cutters used to trim down the base volume to the maximum height. Then it iterates over each list of lot edges on the zoning lot, using them as inputs to `build_yard_cutter`.

# %% [markdown]
# When `generate_envelope` is called, the ZoningLot object uses `build_base_volume` to get the unrestricted volumetric area on the zoning lot. Then it calls `get_additives` and `get_subtractives` on the current Zone object (`zone`) to get volumes to either add or subtract through boolean operations to obtain the finished zoning envelope.

# %% [markdown]
# Ideally, `build_yard_cutter` would take an edge and the OCC Wire representation of the boundary, and a series of height/setback pairs used to define the contour of the cutting volume.

# %% [markdown]
# In the cell below, provide one or more BBLs to use as the zoning lot, separated by commas. For example:
#
# - `2022850129, 2022850130`
# - `2022850130`

# %%
bbl_form = widgets.Text(
    value='2022850130',
    placeholder='',
    description='BBL(s)',
    disabled=False
)

bbl_form
# Out:
# Text(value='2022850130', description='BBL(s)', placeholder='')

# %%
study = Study('WITH_ACTION')
study.add_scenario(Scenario('A'))

site_bbls = [s.strip() for s in bbl_form.value.split(',')]
study.add_site(Site('1', site_bbls))

zl = study.get_zoning_lot('A', '1')
zl.define_zone('R10X')

# %%
# zl.zone.ht_max = 105
# zl.zone.base_ht_max = 65

# %%
# zl.baseplane_elevation = 30

# %%
(subtractives, results) = zl.generate_envelope()
renderer = JupyterRenderer()
renderer.DisplayShape(zl.geom, render_edges=True, topo_level="default", shape_color="#abdda4", update=True)
renderer.DisplayShape(zl.envelope)
# Out:
# HBox(children=(VBox(children=(HBox(children=(Checkbox(value=True, description='Axes', layout=Layout(height='au…

# %%
bldg = zl.generate_building()

# %%
bldg.floors
# Out:
# [<nyczoning.proposedbuilding.Floor at 0x7f9a5b3faa50>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b3fa3d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b3faed0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b3faf10>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b3fa310>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b3fa390>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b3faa90>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b3fa750>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b3fa290>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b3fa210>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5c9cde10>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b3fa4d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b3fa990>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b3fa110>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b3fab50>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5c9db910>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b3fae50>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b3facd0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b3fa910>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b3fa190>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b3fa610>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b4258d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b425850>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b4257d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b4256d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b425290>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b4254d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b425190>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a638f0d90>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b425fd0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a63775310>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b425d10>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b425d50>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b425e90>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b425090>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a62d25ad0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be4b7d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b425690>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b425ad0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a63775090>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be94790>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be94f90>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be94410>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be94890>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be7fe90>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be7f950>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be7f790>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be7f710>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be7f550>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be7f810>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be7f2d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be7f310>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be7f290>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be5d950>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be7fd50>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be7f990>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be7ff10>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be7f390>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be7f490>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be7f590>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be7f150>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be5cf50>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be5c1d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be5c990>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a63784550>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be5c0d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be5c090>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be5ca90>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a63775d90>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be5cb50>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be5c590>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be5cf10>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be5cc90>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be5ca50>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be5cf90>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be5c9d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be943d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be4b2d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be5c650>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a638faa10>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a638fac10>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a638fad90>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be4b090>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a63908910>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a63908950>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a639087d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a63908a10>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be5c690>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a63908e90>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b40f850>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b40f450>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a63908ad0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b40fad0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b40f810>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b40f150>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b40f2d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b40ff50>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b40f510>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a637845d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b40f790>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b40f8d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b40ff90>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b40f9d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b40fa50>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b40fb50>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b40f490>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5b40f710>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5bea20d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5bea24d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5bea23d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5bea2550>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5bea2650>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5bea2690>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5bea2910>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5bea2610>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5bea29d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5bea2b10>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5bea2950>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5bea2a10>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5bea2dd0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5bea2250>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5bea28d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a62e47750>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be5d350>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be5d190>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be5d050>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be5d210>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be5d110>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be4bfd0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be5d250>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be5d1d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be5d150>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be5d090>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be5d310>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be5d290>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be5d2d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a63775390>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5bea2890>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5bea2f90>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5bea2e10>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5bea2d10>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5bea2150>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a63775250>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5bea2410>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5bea2e90>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5be4b650>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5bea2c90>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd32d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd3450>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd34d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd3550>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd35d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd3650>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd36d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd3750>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd37d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd3850>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd38d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd3950>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd39d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a63775610>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd3250>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd3b10>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd3b90>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a63775190>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd30d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd3cd0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd3d50>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd3dd0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd3e50>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd3ed0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd3f50>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd3fd0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd33d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd3c10>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd3150>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd3a50>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a63852d90>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd31d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd3350>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd63d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd6450>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd64d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd6550>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd65d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd6650>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd66d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd6750>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd67d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd6850>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd68d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd6950>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd69d0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd6a50>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd6ad0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd6b50>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd6bd0>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd6c50>,
#  <nyczoning.proposedbuilding.Floor at 0x7f9a5ddd6cd0>]

# %%
# bldg_summary = bldg.summarize()

# %%
for f in bldg.floors:
    print(f'Floor {f.level} | Area: {f.area} | Height: {f.height}')
    renderer.DisplayShape(f.geom, render_edges=True, shape_color="#abdda4")
# Out:
# Floor 1 | Area: 2178.7957450122185 | Height: 15.0
# Floor 2 | Area: 1536.1335388175137 | Height: 10.0
# Floor 3 | Area: 1536.1335388175137 | Height: 10.0
# Floor 4 | Area: 1536.1335388175137 | Height: 10.0
# Floor 5 | Area: 1536.1335388175137 | Height: 10.0
# Floor 6 | Area: 1536.1335388175137 | Height: 10.0
# Floor 7 | Area: 1536.1335388175137 | Height: 10.0
# Floor 8 | Area: 1536.1335388175137 | Height: 10.0
# Floor 9 | Area: 1214.8033653074197 | Height: 10.0
# Floor 10 | Area: 1214.8033653074197 | Height: 10.0
# Floor 11 | Area: 1214.8033653074197 | Height: 10.0
# Floor 12 | Area: 1214.8033653074197 | Height: 10.0
# Floor 13 | Area: 1214.8033653074197 | Height: 10.0
# Floor 14 | Area: 1214.8033653074197 | Height: 10.0
# Floor 15 | Area: 1214.8033653074197 | Height: 10.0
# Floor 16 | Area: 1214.8033653074197 | Height: 10.0
# Floor 17 | Area: 1214.8033653074197 | Height: 10.0
# Floor 18 | Area: 1214.8033653074197 | Height: 10.0
# Floor 19 | Area: 1214.8033653074197 | Height: 10.0
# Floor 20 | Area: 1214.8033653074197 | Height: 10.0
# Floor 21 | Area: 1214.8033653074197 | Height: 10.0
# Floor 22 | Area: 1214.8033653074197 | Height: 10.0
# Floor 23 | Area: 1214.8033653074197 | Height: 10.0
# Floor 24 | Area: 1214.8033653074197 | Height: 10.0
# Floor 25 | Area: 1214.8033653074197 | Height: 10.0
# Floor 26 | Area: 1214.8033653074197 | Height: 10.0
# Floor 27 | Area: 1214.8033653074197 | Height: 10.0
# Floor 28 | Area: 1214.8033653074197 | Height: 10.0
# Floor 29 | Area: 1214.8033653074197 | Height: 10.0
# Floor 30 | Area: 1214.8033653074197 | Height: 10.0
# Floor 31 | Area: 1214.8033653074197 | Height: 10.0
# Floor 32 | Area: 1214.8033653074197 | Height: 10.0
# Floor 33 | Area: 1214.8033653074197 | Height: 10.0
# Floor 34 | Area: 1214.8033653074197 | Height: 10.0
# Floor 35 | Area: 1214.8033653074197 | Height: 10.0
# Floor 36 | Area: 1214.8033653074197 | Height: 10.0
# Floor 37 | Area: 1214.8033653074197 | Height: 10.0
# Floor 38 | Area: 1214.8033653074197 | Height: 10.0
# Floor 39 | Area: 1214.8033653074197 | Height: 10.0
# Floor 40 | Area: 1214.8033653074197 | Height: 10.0
# Floor 41 | Area: 1214.8033653074197 | Height: 10.0
# Floor 42 | Area: 1214.8033653074197 | Height: 10.0
# Floor 43 | Area: 1214.8033653074197 | Height: 10.0
# Floor 44 | Area: 1214.8033653074197 | Height: 10.0
# Floor 45 | Area: 1214.8033653074197 | Height: 10.0
# Floor 46 | Area: 1214.8033653074197 | Height: 10.0
# Floor 47 | Area: 1214.8033653074197 | Height: 10.0
# Floor 48 | Area: 1214.8033653074197 | Height: 10.0
# Floor 49 | Area: 1214.8033653074197 | Height: 10.0
# Floor 50 | Area: 1214.8033653074197 | Height: 10.0
# Floor 51 | Area: 1214.8033653074197 | Height: 10.0
# Floor 52 | Area: 1214.8033653074197 | Height: 10.0
# Floor 53 | Area: 1214.8033653074197 | Height: 10.0
# Floor 54 | Area: 1214.8033653074197 | Height: 10.0
# Floor 55 | Area: 1214.8033653074197 | Height: 10.0
# Floor 56 | Area: 1214.8033653074197 | Height: 10.0
# Floor 57 | Area: 1214.8033653074197 | Height: 10.0
# Floor 58 | Area: 1214.8033653074197 | Height: 10.0
# Floor 59 | Area: 1214.8033653074197 | Height: 10.0
# Floor 60 | Area: 1214.8033653074197 | Height: 10.0
# Floor 61 | Area: 1214.8033653074197 | Height: 10.0
# Floor 62 | Area: 1214.8033653074197 | Height: 10.0
# Floor 63 | Area: 1214.8033653074197 | Height: 10.0
# Floor 64 | Area: 1214.8033653074197 | Height: 10.0
# Floor 65 | Area: 1214.8033653074197 | Height: 10.0
# Floor 66 | Area: 1214.8033653074197 | Height: 10.0
# Floor 67 | Area: 1214.8033653074197 | Height: 10.0
# Floor 68 | Area: 1214.8033653074197 | Height: 10.0
# Floor 69 | Area: 1214.8033653074197 | Height: 10.0
# Floor 70 | Area: 1214.8033653074197 | Height: 10.0
# Floor 71 | Area: 1214.8033653074197 | Height: 10.0
# Floor 72 | Area: 1214.8033653074197 | Height: 10.0
# Floor 73 | Area: 1214.8033653074197 | Height: 10.0
# Floor 74 | Area: 1214.8033653074197 | Height: 10.0
# Floor 75 | Area: 1214.8033653074197 | Height: 10.0
# Floor 76 | Area: 1214.8033653074197 | Height: 10.0
# Floor 77 | Area: 1214.8033653074197 | Height: 10.0
# Floor 78 | Area: 1214.8033653074197 | Height: 10.0
# Floor 79 | Area: 1214.8033653074197 | Height: 10.0
# Floor 80 | Area: 1214.8033653074197 | Height: 10.0
# Floor 81 | Area: 1214.8033653074197 | Height: 10.0
# Floor 82 | Area: 1214.8033653074197 | Height: 10.0
# Floor 83 | Area: 1214.8033653074197 | Height: 10.0
# Floor 84 | Area: 1214.8033653074197 | Height: 10.0
# Floor 85 | Area: 1214.8033653074197 | Height: 10.0
# Floor 86 | Area: 1214.8033653074197 | Height: 10.0
# Floor 87 | Area: 1214.8033653074197 | Height: 10.0
# Floor 88 | Area: 1214.8033653074197 | Height: 10.0
# Floor 89 | Area: 1214.8033653074197 | Height: 10.0
# Floor 90 | Area: 1214.8033653074197 | Height: 10.0
# Floor 91 | Area: 1214.8033653074197 | Height: 10.0
# Floor 92 | Area: 1214.8033653074197 | Height: 10.0
# Floor 93 | Area: 1214.8033653074197 | Height: 10.0
# Floor 94 | Area: 1214.8033653074197 | Height: 10.0
# Floor 95 | Area: 1214.8033653074197 | Height: 10.0
# Floor 96 | Area: 1214.8033653074197 | Height: 10.0
# Floor 97 | Area: 1214.8033653074197 | Height: 10.0
# Floor 98 | Area: 1214.8033653074197 | Height: 10.0
# Floor 99 | Area: 1214.8033653074197 | Height: 10.0
# Floor 100 | Area: 1214.8033653074197 | Height: 10.0
# Floor 101 | Area: 1214.8033653074197 | Height: 10.0
# Floor 102 | Area: 1214.8033653074197 | Height: 10.0
# Floor 103 | Area: 1214.8033653074197 | Height: 10.0
# Floor 104 | Area: 1214.8033653074197 | Height: 10.0
# Floor 105 | Area: 1214.8033653074197 | Height: 10.0
# Floor 106 | Area: 1214.8033653074197 | Height: 10.0
# Floor 107 | Area: 1214.8033653074197 | Height: 10.0
# Floor 108 | Area: 1214.8033653074197 | Height: 10.0
# Floor 109 | Area: 1214.8033653074197 | Height: 10.0
# Floor 110 | Area: 1214.8033653074197 | Height: 10.0
# Floor 111 | Area: 1214.8033653074197 | Height: 10.0
# Floor 112 | Area: 1214.8033653074197 | Height: 10.0
# Floor 113 | Area: 1214.8033653074197 | Height: 10.0
# Floor 114 | Area: 1214.8033653074197 | Height: 10.0
# Floor 115 | Area: 1214.8033653074197 | Height: 10.0
# Floor 116 | Area: 1214.8033653074197 | Height: 10.0
# Floor 117 | Area: 1214.8033653074197 | Height: 10.0
# Floor 118 | Area: 1214.8033653074197 | Height: 10.0
# Floor 119 | Area: 1214.8033653074197 | Height: 10.0
# Floor 120 | Area: 1214.8033653074197 | Height: 10.0
# Floor 121 | Area: 1214.8033653074197 | Height: 10.0
# Floor 122 | Area: 1214.8033653074197 | Height: 10.0
# Floor 123 | Area: 1214.8033653074197 | Height: 10.0
# Floor 124 | Area: 1214.8033653074197 | Height: 10.0
# Floor 125 | Area: 1214.8033653074197 | Height: 10.0
# Floor 126 | Area: 1214.8033653074197 | Height: 10.0
# Floor 127 | Area: 1214.8033653074197 | Height: 10.0
# Floor 128 | Area: 1214.8033653074197 | Height: 10.0
# Floor 129 | Area: 1214.8033653074197 | Height: 10.0
# Floor 130 | Area: 1214.8033653074197 | Height: 10.0
# Floor 131 | Area: 1214.8033653074197 | Height: 10.0
# Floor 132 | Area: 1214.8033653074197 | Height: 10.0
# Floor 133 | Area: 1214.8033653074197 | Height: 10.0
# Floor 134 | Area: 1214.8033653074197 | Height: 10.0
# Floor 135 | Area: 1214.8033653074197 | Height: 10.0
# Floor 136 | Area: 1214.8033653074197 | Height: 10.0
# Floor 137 | Area: 1214.8033653074197 | Height: 10.0
# Floor 138 | Area: 1214.8033653074197 | Height: 10.0
# Floor 139 | Area: 1214.8033653074197 | Height: 10.0
# Floor 140 | Area: 1214.8033653074197 | Height: 10.0
# Floor 141 | Area: 1214.8033653074197 | Height: 10.0
# Floor 142 | Area: 1214.8033653074197 | Height: 10.0
# Floor 143 | Area: 1214.8033653074197 | Height: 10.0
# Floor 144 | Area: 1214.8033653074197 | Height: 10.0
# Floor 145 | Area: 1214.8033653074197 | Height: 10.0
# Floor 146 | Area: 1214.8033653074197 | Height: 10.0
# Floor 147 | Area: 1214.8033653074197 | Height: 10.0
# Floor 148 | Area: 1214.8033653074197 | Height: 10.0
# Floor 149 | Area: 1214.8033653074197 | Height: 10.0
# Floor 150 | Area: 1214.8033653074197 | Height: 10.0
# Floor 151 | Area: 1214.8033653074197 | Height: 10.0
# Floor 152 | Area: 1214.8033653074197 | Height: 10.0
# Floor 153 | Area: 1214.8033653074197 | Height: 10.0
# Floor 154 | Area: 1214.8033653074197 | Height: 10.0
# Floor 155 | Area: 1214.8033653074197 | Height: 10.0
# Floor 156 | Area: 1214.8033653074197 | Height: 10.0
# Floor 157 | Area: 1214.8033653074197 | Height: 10.0
# Floor 158 | Area: 1214.8033653074197 | Height: 10.0
# Floor 159 | Area: 1214.8033653074197 | Height: 10.0
# Floor 160 | Area: 1214.8033653074197 | Height: 10.0
# Floor 161 | Area: 1214.8033653074197 | Height: 10.0
# Floor 162 | Area: 1214.8033653074197 | Height: 10.0
# Floor 163 | Area: 1214.8033653074197 | Height: 10.0
# Floor 164 | Area: 1214.8033653074197 | Height: 10.0
# Floor 165 | Area: 1214.8033653074197 | Height: 10.0
# Floor 166 | Area: 1214.8033653074197 | Height: 10.0
# Floor 167 | Area: 1214.8033653074197 | Height: 10.0
# Floor 168 | Area: 1214.8033653074197 | Height: 10.0
# Floor 169 | Area: 1214.8033653074197 | Height: 10.0
# Floor 170 | Area: 1214.8033653074197 | Height: 10.0
# Floor 171 | Area: 1214.8033653074197 | Height: 10.0
# Floor 172 | Area: 1214.8033653074197 | Height: 10.0
# Floor 173 | Area: 1214.8033653074197 | Height: 10.0
# Floor 174 | Area: 1214.8033653074197 | Height: 10.0
# Floor 175 | Area: 1214.8033653074197 | Height: 10.0
# Floor 176 | Area: 1214.8033653074197 | Height: 10.0
# Floor 177 | Area: 1214.8033653074197 | Height: 10.0
# Floor 178 | Area: 1214.8033653074197 | Height: 10.0
# Floor 179 | Area: 1214.8033653074197 | Height: 10.0
# Floor 180 | Area: 1214.8033653074197 | Height: 10.0
# Floor 181 | Area: 1214.8033653074197 | Height: 10.0
# Floor 182 | Area: 1214.8033653074197 | Height: 10.0
# Floor 183 | Area: 1214.8033653074197 | Height: 10.0
# Floor 184 | Area: 1214.8033653074197 | Height: 10.0
# Floor 185 | Area: 1214.8033653074197 | Height: 10.0
# Floor 186 | Area: 1214.8033653074197 | Height: 10.0
# Floor 187 | Area: 1214.8033653074197 | Height: 10.0
# Floor 188 | Area: 1214.8033653074197 | Height: 10.0
# Floor 189 | Area: 1214.8033653074197 | Height: 10.0
# Floor 190 | Area: 1214.8033653074197 | Height: 10.0
# Floor 191 | Area: 1214.8033653074197 | Height: 10.0
# Floor 192 | Area: 1214.8033653074197 | Height: 10.0
# Floor 193 | Area: 1214.8033653074197 | Height: 10.0
# Floor 194 | Area: 1214.8033653074197 | Height: 10.0
# Floor 195 | Area: 1214.8033653074197 | Height: 10.0
# Floor 196 | Area: 1214.8033653074197 | Height: 10.0
# Floor 197 | Area: 1214.8033653074197 | Height: 10.0
# Floor 198 | Area: 1214.8033653074197 | Height: 10.0
# Floor 199 | Area: 1214.8033653074197 | Height: 10.0

# %% [markdown]
# ## Checklist
#
# - [x] `build_height_cutter` working
# - [x] `build_yard_cutter` working
#     - [x] implemented for rear yards
#     - [x] implemented for front yards
#     - [ ] implemented for side yards

# %%
# export zoning lot, edges & bounds

# with open('./assets/20210921_edge850.pickle', 'wb') as f:
#   pickle.dump(zl.edges[850]['geom'], f)
  
# with open('./assets/20210921_bounds2022850130.pickle', 'wb') as f:
#   pickle.dump(zl.geom, f)

# with open('./assets/20210928_zl.pickle', 'wb') as f:
#   pickle.dump(zl, f)
